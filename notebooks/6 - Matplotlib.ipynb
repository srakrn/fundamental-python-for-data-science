# %% [markdown]
# *Composed by Sirakorn Lamyai, Kasetsart University*
#
# ---

# %% [markdown]
# # Matplotlib
#
# Matplotlib is a plotting library in Python, gaining popularities in the Python Data Science Community.

# %%
import numpy as np

# %% [markdown]
# # Initialising Matplotlib
#
# Matplotlib is a relatively large library. Most of the time, we'll only use the `pyplot` module. Therefore, we would usually import the module as follows.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # *Dirty* plots
#
# When we mean by dirty plots, This is what we meant: a single plot command, and a show command.

# %%
plt.plot([1, 1, 2, 3, 5, 8])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 4, 8, 16])
plt.show()

# %%
plt.scatter([1, 1, 2, 3, 5, 8], [2, 0, 4, 1, 1, 1])
plt.show()

# %% [markdown]
# # Understanding Matplotlib Components
#
# ## Figure

# %%
fig = plt.figure()
plt.show()

# %% [markdown]
# ## Axes and Subplots

# %%
fig = plt.figure()
ax = plt.axes()
plt.show()

# %%
fix, ax_list = plt.subplots(2, 3)
plt.show()

# %%
ax_list
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fbcee44e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fbcf04f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fbcec1390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fbce70940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fbce23ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fbcddf4e0>]],
#       dtype=object)

# %% [markdown]
# # Plots

# %% [markdown]
# ## Line plots

# %%
t = np.linspace(0, 2*np.pi, 100)

fig, ax = plt.subplots(2, 1)

ax[0].plot(t, np.sin(t))
ax[1].plot(t, np.cos(t))

plt.show()

# %% [markdown]
# ## Scatter plots

# %%
x = np.linspace(1, 10, 100) + np.random.uniform(0, 2, 100)
y = np.linspace(5, 20, 100) + np.random.uniform(0, 2, 100)

# %%
fig = plt.figure()
ax = plt.axes()

ax.scatter(x, y)

plt.show()

# %% [markdown]
# ## Histogram

# %%
fig = plt.figure()
ax = plt.axes()

ax.hist(x)

plt.show()

# %% [markdown]
# # Legends and Labels

# %%
fig = plt.figure()
ax = plt.axes()

ax.plot(t, np.sin(t), label="sin(x)")
ax.plot(t, np.cos(t), label="cos(x)")

plt.legend()

plt.show()

# %%
fig = plt.figure()
ax = plt.axes()

ax.plot(t, np.sin(t))
ax.plot(t, np.cos(t))

ax.set_xlabel("Time [s]")
ax.set_ylabel("Function value")

plt.show()

# %%
fig = plt.figure()
ax = plt.axes()

ax.plot(t, np.sin(t))
ax.plot(t, np.cos(t))

ax.set_title("sin and cos function")

plt.show()

# %% [markdown]
# ## Basic LaTeX

# %%
fig = plt.figure()
ax = plt.axes()

ax.plot(t, 3*t + (1/2)*2*t**2)
ax.set_title(r"$s = 3t + \frac{1}{2} \left( 2 \right) t^2$")

plt.show()

# %%
fig = plt.figure()
ax = plt.axes()

ax.plot(t, np.cos(2*np.pi*0.5*t))
ax.set_title(r"$\omega = \cos\left(2 \pi \left( 0.5 \right) t \right)$")

plt.show()

# %% [markdown]
# # Customising plots

# %%
t = np.linspace(0, 2*np.pi, 100)

fig, ax = plt.subplots(2, 1)

ax[0].plot(t, np.sin(t))
ax[1].plot(t, np.cos(t))

plt.show()

# %%
t = np.linspace(0, 2*np.pi, 100)

fig, ax = plt.subplots(2, 1)

ax[0].plot(t, np.sin(t), color="red")
ax[1].plot(t, np.cos(t), linewidth=5)

plt.show()

# %%
t = np.linspace(0, 0.5*np.pi, 10)

fig, ax = plt.subplots(2, 1)

ax[0].plot(t, np.sin(t), marker='o')
ax[1].plot(t, np.cos(t), marker='^', markerfacecolor="red", markeredgecolor="red")

plt.show()

# %%
t = np.linspace(0, 0.5*np.pi, 10)

fig, ax = plt.subplots(2, 1)

ax[0].plot(t, np.sin(t), linestyle='--')
ax[1].plot(t, np.cos(t), linestyle=':')

plt.show()

# %%
t = np.linspace(0, 0.5*np.pi, 10)

fig, ax = plt.subplots(2, 1)

ax[0].plot(t, np.sin(t), 'r+-')
ax[1].plot(t, np.cos(t), 'go--')

plt.show()

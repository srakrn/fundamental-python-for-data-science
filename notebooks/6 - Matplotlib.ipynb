# %% [markdown]
# *Composed by Sirakorn Lamyai, Kasetsart University*
#
# ---

# %% [markdown]
# # Matplotlib
#
# Matplotlib is a plotting library in Python, gaining popularities in the Python Data Science Community.

# %%
import numpy as np

# %% [markdown]
# # Initialising Matplotlib
#
# Matplotlib is a relatively large library. Most of the time, we'll only use the `pyplot` module. Therefore, we would usually import the module as follows.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # *Dirty* plots
#
# When we mean by dirty plots, This is what we meant: a single plot command, and a show command.

# %%
plt.plot([1, 1, 2, 3, 5, 8])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 4, 8, 16])
plt.show()

# %%
plt.scatter([1, 1, 2, 3, 5, 8], [2, 0, 4, 1, 1, 1])
plt.show()

# %% [markdown]
# # Understanding Matplotlib Components
#
# ## Figure

# %%
fig = plt.figure()
plt.show()

# %% [markdown]
# ## Axes and Subplots

# %%
fig = plt.figure()
ax = plt.axes()
plt.show()

# %%
fix, ax_list = plt.subplots(2, 3)
plt.show()

# %%
ax_list
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbff9e38a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbff9de52b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbff9e167b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbff9dc9d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbff9d85358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbff9d37908>]],
#       dtype=object)

# %% [markdown]
# # Plots

# %% [markdown]
# ## Line plots

# %%
t = np.linspace(0, 2*np.pi, 100)

fig, ax = plt.subplots(2, 1)

ax[0].plot(t, np.sin(t))
ax[1].plot(t, np.cos(t))

plt.show()

# %% [markdown]
# ## Scatter plots

# %%
x = np.linspace(1, 10, 100) + np.random.normal(0, 1, 100)
y = np.linspace(5, 20, 100) + np.random.normal(0, 1, 100)
z = np.random.uniform(50, 200, 100)
c = np.random.uniform(0, 100, 100)

# %%
fig = plt.figure()
ax = plt.axes()

ax.scatter(x, y)

plt.show()

# %%
fig = plt.figure()
ax = plt.axes()

ax.scatter(x, y, s=z)

plt.show()

# %% [markdown]
# ## Histogram

# %%
fig = plt.figure()
ax = plt.axes()

ax.hist(x)

plt.show()

# %% [markdown]
# # Legends and Labels

# %%
fig = plt.figure()
ax = plt.axes()

ax.plot(t, np.sin(t), label="sin(x)")
ax.plot(t, np.cos(t), label="cos(x)")

plt.legend()

plt.show()

# %%
fig = plt.figure()
ax = plt.axes()

ax.plot(t, np.sin(t))
ax.plot(t, np.cos(t))

ax.set_xlabel("Time [s]")
ax.set_ylabel("Function value")

plt.show()

# %%
fig = plt.figure()
ax = plt.axes()

ax.plot(t, np.sin(t))
ax.plot(t, np.cos(t))

ax.set_title("sin and cos function")

plt.show()

# %% [markdown]
# ## Basic LaTeX

# %%
fig = plt.figure()
ax = plt.axes()

ax.plot(t, 3*t + (1/2)*2*t**2)
ax.set_title(r"$s = 3t + \frac{1}{2} \left( 2 \right) t^2$")

plt.show()

# %%
fig = plt.figure()
ax = plt.axes()

ax.plot(t, np.cos(2*np.pi*0.5*t))
ax.set_title(r"$\omega = \cos\left(2 \pi \left( 0.5 \right) t \right)$")

plt.show()

# %% [markdown]
# # Customising plots

# %% [markdown]
# ## Line plots

# %%
t = np.linspace(0, 2*np.pi, 100)

# %%
fig, ax = plt.subplots(2, 1)

ax[0].plot(t, np.sin(t))
ax[1].plot(t, np.cos(t))

plt.show()

# %%
fig, ax = plt.subplots(2, 1)

ax[0].plot(t, np.sin(t), color="red")
ax[1].plot(t, np.cos(t), linewidth=5)

plt.show()

# %%
fig, ax = plt.subplots(2, 1)

ax[0].plot(t, np.sin(t), marker='o')
ax[1].plot(t, np.cos(t), marker='^', markerfacecolor="red", markeredgecolor="red")

plt.show()

# %%
fig, ax = plt.subplots(2, 1)

ax[0].plot(t, np.sin(t), linestyle='--')
ax[1].plot(t, np.cos(t), linestyle=':')

plt.show()

# %%
fig, ax = plt.subplots(2, 1)

ax[0].plot(t, np.sin(t), 'r+-')
ax[1].plot(t, np.cos(t), 'go--')

plt.show()

# %% [markdown]
# ## Scatter plots

# %%
fig = plt.figure()
ax = plt.axes()

ax.scatter(x, y, s=z, c=c)

plt.show()

# %%
fig = plt.figure()
ax = plt.axes()

ax.scatter(x, y, s=z, c=c, alpha=0.7)

plt.show()

# %%
fig = plt.figure()
ax = plt.axes()

ax.scatter(x, y, s=z, c=c, alpha=0.7, cmap="Spectral")

plt.show()

# %% [markdown]
# ## Figure

# %%
fig = plt.figure(figsize=(10, 5))
ax = plt.axes()

ax.scatter(x, y, s=z, c=c, alpha=0.7, cmap="Spectral")

ax.set_xlim(0, 10)
ax.set_ylim(0, 20)

plt.show()

# %% [markdown]
# ## Axis

# %%
fig = plt.figure()
ax = plt.axes()

ax.scatter(x, y, s=z, c=c, alpha=0.7, cmap="Spectral")

ax.set_xlim(0, 10)
ax.set_ylim(0, 20)

plt.show()
